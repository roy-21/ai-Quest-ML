# %%
import pandas as pd 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# 13         91992.39       135495.07  252664.93      Ctg  134307.35
# 14        119943.24       156547.42  256512.92  Rangpur  132602.65
# 15        165349.20       122616.84  261776.23    Dhaka  129917.04
# 16         78013.11       121597.55  264346.06      Ctg  126992.93
# 17         94657.16       145077.58  282574.31    Dhaka  125370.37
# 18         91749.16       114175.79  294919.57  Rangpur  124266.90
# 19         86419.70       153514.11        NaN    Dhaka  122776.86
# 20         76253.86       113867.30  298664.47      Ctg  118474.03
# 21         78389.47       153773.43  299737.29    Dhaka  111313.02
# 22         73994.56       122782.75  303319.26  Rangpur  110352.25
# 23         67532.53       105751.03  304768.73  Rangpur  108733.99
# 24         77044.01        99281.34  140574.81    Dhaka  108552.04
# 25         64664.71       139553.16  137962.62      Ctg  107404.34
# 26         75328.87       144135.98  134050.07  Rangpur  105733.54
# 27         72107.60       127864.55  353183.81    Dhaka  105008.31
# 28         66051.52       182645.56  118148.20  Rangpur  103282.38
# 29         65605.48       153032.06  107138.38    Dhaka  101004.64
# 30         61994.48       115641.28   91131.24  Rangpur   99937.59
# 31         61136.38       152701.92   88218.23    Dhaka   97483.56
# 32         63408.86       129219.61   46085.25      Ctg   97427.84
# 33         55493.95       103057.49  214634.81  Rangpur   96778.92
# 34         46426.07       157693.92  210797.67      Ctg   96712.80
# 35         46014.02        85047.44  205517.64    Dhaka   96479.51
# 36         28663.76       127056.21  201126.82  Rangpur   90708.19
# 37         44069.95        51283.14  197029.42      Ctg   89949.14
# 38         20229.59        65947.93  185265.10    Dhaka   81229.06
# 39         38558.51        82982.09  174999.30      Ctg   81005.76
# 40         28754.33       118546.05  172795.67      Ctg   78239.91
# 41         27892.92        84710.77  164470.71  Rangpur   77798.83
# 42         23640.93        96189.63  148001.11      Ctg   71498.49
# 43         15505.73       127382.30   35534.17    Dhaka   69758.98
# 44         22177.74       154806.14   28334.72      Ctg   65200.33
# 45          1000.23       124153.04    1903.93    Dhaka   64926.08
# 46          1315.46       115816.21  297114.46  Rangpur   49490.75
# 47             0.00       135426.92       0.00      Ctg   42559.73
# 48           542.05        51743.15       0.00    Dhaka   35673.41
# 49             0.00       116983.80   45173.06      Ctg   14681.40

# %%
x =  df.drop('Profit', axis=1)

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
x.isnull().sum() #checking null values
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# dtype: int64

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df[18:21] # to see the row from 18 to 20
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 18         91749.16       114175.79  294919.57  Rangpur  124266.90
# 19         86419.70       153514.11        NaN    Dhaka  122776.86
# 20         76253.86       113867.30  298664.47      Ctg  118474.03

# %%
import seaborn as sns

# %%
sns.histplot(df.Transport, kde=True,bins=50)
# Out:
# <Axes: xlabel='Transport', ylabel='Count'>

# %% [markdown]
# # Measure of Central Tendency

# %%
df.Transport.mean() #no outliers
# Out:
# np.float64(215331.7324489796)

# %%
df.Transport.median() #outliers exist
# Out:
# np.float64(214634.81)

# %%
mean = df.Transport.mean()
mean
# Out:
# np.float64(215331.7324489796)

# %%
df.Transport = df.Transport.fillna(mean) #mean diye NaN value fillup korbe
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
mean
# Out:
# np.float64(215331.7324489796)

# %%
df[18:21]
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86
# 20         76253.86       113867.30  298664.470000      Ctg  118474.03

# %%
df2.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df2.Transport = df2.Transport.fillna(mean) #mean diye NaN value fillup korbe
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df2[18:21]
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86
# 20         76253.86       113867.30  298664.470000      Ctg  118474.03

# %%
df3
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# 13         91992.39       135495.07  252664.93      Ctg  134307.35
# 14        119943.24       156547.42  256512.92  Rangpur  132602.65
# 15        165349.20       122616.84  261776.23    Dhaka  129917.04
# 16         78013.11       121597.55  264346.06      Ctg  126992.93
# 17         94657.16       145077.58  282574.31    Dhaka  125370.37
# 18         91749.16       114175.79  294919.57  Rangpur  124266.90
# 19         86419.70       153514.11        NaN    Dhaka  122776.86
# 20         76253.86       113867.30  298664.47      Ctg  118474.03
# 21         78389.47       153773.43  299737.29    Dhaka  111313.02
# 22         73994.56       122782.75  303319.26  Rangpur  110352.25
# 23         67532.53       105751.03  304768.73  Rangpur  108733.99
# 24         77044.01        99281.34  140574.81    Dhaka  108552.04
# 25         64664.71       139553.16  137962.62      Ctg  107404.34
# 26         75328.87       144135.98  134050.07  Rangpur  105733.54
# 27         72107.60       127864.55  353183.81    Dhaka  105008.31
# 28         66051.52       182645.56  118148.20  Rangpur  103282.38
# 29         65605.48       153032.06  107138.38    Dhaka  101004.64
# 30         61994.48       115641.28   91131.24  Rangpur   99937.59
# 31         61136.38       152701.92   88218.23    Dhaka   97483.56
# 32         63408.86       129219.61   46085.25      Ctg   97427.84
# 33         55493.95       103057.49  214634.81  Rangpur   96778.92
# 34         46426.07       157693.92  210797.67      Ctg   96712.80
# 35         46014.02        85047.44  205517.64    Dhaka   96479.51
# 36         28663.76       127056.21  201126.82  Rangpur   90708.19
# 37         44069.95        51283.14  197029.42      Ctg   89949.14
# 38         20229.59        65947.93  185265.10    Dhaka   81229.06
# 39         38558.51        82982.09  174999.30      Ctg   81005.76
# 40         28754.33       118546.05  172795.67      Ctg   78239.91
# 41         27892.92        84710.77  164470.71  Rangpur   77798.83
# 42         23640.93        96189.63  148001.11      Ctg   71498.49
# 43         15505.73       127382.30   35534.17    Dhaka   69758.98
# 44         22177.74       154806.14   28334.72      Ctg   65200.33
# 45          1000.23       124153.04    1903.93    Dhaka   64926.08
# 46          1315.46       115816.21  297114.46  Rangpur   49490.75
# 47             0.00       135426.92       0.00      Ctg   42559.73
# 48           542.05        51743.15       0.00    Dhaka   35673.41
# 49             0.00       116983.80   45173.06      Ctg   14681.40

# %%
df3.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df3.Transport=df3.Transport.fillna(mean)
df3.Transport
# Out:
# 0     471784.100000
# 1     443898.530000
# 2     407934.540000
# 3     383199.620000
# 4     366168.420000
# 5     362861.360000
# 6     127716.820000
# 7     323876.680000
# 8     311613.290000
# 9     304981.620000
# 10    229160.950000
# 11    249744.550000
# 12    249839.440000
# 13    252664.930000
# 14    256512.920000
# 15    261776.230000
# 16    264346.060000
# 17    282574.310000
# 18    294919.570000
# 19    215331.732449
# 20    298664.470000
# 21    299737.290000
# 22    303319.260000
# 23    304768.730000
# 24    140574.810000
# 25    137962.620000
# 26    134050.070000
# 27    353183.810000
# 28    118148.200000
# 29    107138.380000
# 30     91131.240000
# 31     88218.230000
# 32     46085.250000
# 33    214634.810000
# 34    210797.670000
# 35    205517.640000
# 36    201126.820000
# 37    197029.420000
# 38    185265.100000
# 39    174999.300000
# 40    172795.670000
# 41    164470.710000
# 42    148001.110000
# 43     35534.170000
# 44     28334.720000
# 45      1903.930000
# 46    297114.460000
# 47         0.000000
# 48         0.000000
# 49     45173.060000
# Name: Transport, dtype: float64

# %%
df3[18:21]
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86
# 20         76253.86       113867.30  298664.470000      Ctg  118474.03

# %%
df4
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# 13         91992.39       135495.07  252664.93      Ctg  134307.35
# 14        119943.24       156547.42  256512.92  Rangpur  132602.65
# 15        165349.20       122616.84  261776.23    Dhaka  129917.04
# 16         78013.11       121597.55  264346.06      Ctg  126992.93
# 17         94657.16       145077.58  282574.31    Dhaka  125370.37
# 18         91749.16       114175.79  294919.57  Rangpur  124266.90
# 19         86419.70       153514.11        NaN    Dhaka  122776.86
# 20         76253.86       113867.30  298664.47      Ctg  118474.03
# 21         78389.47       153773.43  299737.29    Dhaka  111313.02
# 22         73994.56       122782.75  303319.26  Rangpur  110352.25
# 23         67532.53       105751.03  304768.73  Rangpur  108733.99
# 24         77044.01        99281.34  140574.81    Dhaka  108552.04
# 25         64664.71       139553.16  137962.62      Ctg  107404.34
# 26         75328.87       144135.98  134050.07  Rangpur  105733.54
# 27         72107.60       127864.55  353183.81    Dhaka  105008.31
# 28         66051.52       182645.56  118148.20  Rangpur  103282.38
# 29         65605.48       153032.06  107138.38    Dhaka  101004.64
# 30         61994.48       115641.28   91131.24  Rangpur   99937.59
# 31         61136.38       152701.92   88218.23    Dhaka   97483.56
# 32         63408.86       129219.61   46085.25      Ctg   97427.84
# 33         55493.95       103057.49  214634.81  Rangpur   96778.92
# 34         46426.07       157693.92  210797.67      Ctg   96712.80
# 35         46014.02        85047.44  205517.64    Dhaka   96479.51
# 36         28663.76       127056.21  201126.82  Rangpur   90708.19
# 37         44069.95        51283.14  197029.42      Ctg   89949.14
# 38         20229.59        65947.93  185265.10    Dhaka   81229.06
# 39         38558.51        82982.09  174999.30      Ctg   81005.76
# 40         28754.33       118546.05  172795.67      Ctg   78239.91
# 41         27892.92        84710.77  164470.71  Rangpur   77798.83
# 42         23640.93        96189.63  148001.11      Ctg   71498.49
# 43         15505.73       127382.30   35534.17    Dhaka   69758.98
# 44         22177.74       154806.14   28334.72      Ctg   65200.33
# 45          1000.23       124153.04    1903.93    Dhaka   64926.08
# 46          1315.46       115816.21  297114.46  Rangpur   49490.75
# 47             0.00       135426.92       0.00      Ctg   42559.73
# 48           542.05        51743.15       0.00    Dhaka   35673.41
# 49             0.00       116983.80   45173.06      Ctg   14681.40

# %%
df4.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df4.Transport=df4.Transport.fillna(mean)
df4.Transport
# Out:
# 0     471784.100000
# 1     443898.530000
# 2     407934.540000
# 3     383199.620000
# 4     366168.420000
# 5     362861.360000
# 6     127716.820000
# 7     323876.680000
# 8     311613.290000
# 9     304981.620000
# 10    229160.950000
# 11    249744.550000
# 12    249839.440000
# 13    252664.930000
# 14    256512.920000
# 15    261776.230000
# 16    264346.060000
# 17    282574.310000
# 18    294919.570000
# 19    215331.732449
# 20    298664.470000
# 21    299737.290000
# 22    303319.260000
# 23    304768.730000
# 24    140574.810000
# 25    137962.620000
# 26    134050.070000
# 27    353183.810000
# 28    118148.200000
# 29    107138.380000
# 30     91131.240000
# 31     88218.230000
# 32     46085.250000
# 33    214634.810000
# 34    210797.670000
# 35    205517.640000
# 36    201126.820000
# 37    197029.420000
# 38    185265.100000
# 39    174999.300000
# 40    172795.670000
# 41    164470.710000
# 42    148001.110000
# 43     35534.170000
# 44     28334.720000
# 45      1903.930000
# 46    297114.460000
# 47         0.000000
# 48         0.000000
# 49     45173.060000
# Name: Transport, dtype: float64

# %%
df4[18:21]
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 18         91749.16       114175.79  294919.570000  Rangpur  124266.90
# 19         86419.70       153514.11  215331.732449    Dhaka  122776.86
# 20         76253.86       113867.30  298664.470000      Ctg  118474.03

# %% [markdown]
# # Keep in your mind!

# %% [markdown]
# In machine learning projects, data preprocessing often consumes a significant portion of the total time, while model creation takes a smaller percentage. A common estimate is that data preprocessing can take 60-80% of the project's time, with model creation accounting for 15-20%. The remaining time is typically spent on tasks like data exploration and analysis. More details [read](https://prnt.sc/5ML0AhR3kcDA)

# %% [markdown]
# # Sklearn Preprocessing

# %% [markdown]
# Read sklearn: [Docs](https://scikit-learn.org/stable/modules/preprocessing.html)

# %% [markdown]
# ### Some common encoding techniques in machine learning:
#
# 1. Label Encoding <br>
# 2. One-Hot Encoding <br>
# 3. Binary Encoding <br>
# 4. Ordinal Encoding <br>
# 5. Frequency Encoding <br>
# 6. Mean Encoding <br>
# 7. Text Embedding <br>

# %% [markdown]
# # Label Encoding
#
# Label encoding is a technique used to convert categorical data into numerical labels. Each unique category value is assigned a unique integer. This method is useful when the categorical feature does not have an inherent order and you need to convert the categories to numerical values for machine learning algorithms that can handle categorical variables as numbers.
#
# ## When to Use Label Encoding
#
# Label encoding is appropriate when:
# - The categorical feature does not have a meaningful order.
# - You want to convert categorical values to unique integers for algorithms that can work with numerical labels.
#
# ## Steps to Perform Label Encoding
#
# 1. **Identify unique categories in the feature.**
# 2. **Assign a unique integer to each category.**

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %% [markdown]
# Watch it: [fit Vs. transform](https://youtu.be/0T3MpmbAHXg)

# %%
df1.Area = le.fit_transform(df[['Area']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
le.classes_
# Out:
# array(['Ctg', 'Dhaka', 'Rangpur'], dtype=object)

# %%
le.transform(le.classes_)
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Decode the encoded values back to original classes (Optinal)

# %%
#df.Area = decoded_classes = le.inverse_transform(df1.Area)
decoded_classes = le.inverse_transform(df1.Area) 
decoded_classes
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur', 'Dhaka', 'Rangpur', 'Dhaka', 'Ctg',
#        'Rangpur', 'Dhaka', 'Ctg', 'Rangpur', 'Ctg', 'Rangpur', 'Ctg',
#        'Rangpur', 'Dhaka', 'Ctg', 'Dhaka', 'Rangpur', 'Dhaka', 'Ctg',
#        'Dhaka', 'Rangpur', 'Rangpur', 'Dhaka', 'Ctg', 'Rangpur', 'Dhaka',
#        'Rangpur', 'Dhaka', 'Rangpur', 'Dhaka', 'Ctg', 'Rangpur', 'Ctg',
#        'Dhaka', 'Rangpur', 'Ctg', 'Dhaka', 'Ctg', 'Ctg', 'Rangpur', 'Ctg',
#        'Dhaka', 'Ctg', 'Dhaka', 'Rangpur', 'Ctg', 'Dhaka', 'Ctg'],
#       dtype=object)

# %%
df1.head() #old (after encoding)
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
#After decoding
df1.Area = decoded_classes
df1.head() #new
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Label Encoding with Label mapping

# %%
df.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
label_mapping = {
    'Dhaka': 1, 
    'Rangpur': 2, 
    'Ctg': 0
}

# %%
label_mapping
# Out:
# {'Dhaka': 1, 'Rangpur': 2, 'Ctg': 0}

# %%
label_mapping.keys()
# Out:
# dict_keys(['Dhaka', 'Rangpur', 'Ctg'])

# %%
label_mapping.values()
# Out:
# dict_values([1, 2, 0])

# %%
df2.Area = [label_mapping[area] for area in df2.Area] #List comprehension

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Replace Method

# %%
df3['Area'] = df3['Area'].replace(label_mapping)

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # One Hot Encoder

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
pd.get_dummies(df4['Area']).head()
# Out:
#      Ctg  Dhaka  Rangpur
# 0  False   True    False
# 1   True  False    False
# 2  False  False     True
# 3  False   True    False
# 4  False  False     True

# %%
pd.get_dummies(df4['Area'], drop_first=True).head() #dummy var trap
# Out:
#    Dhaka  Rangpur
# 0   True    False
# 1  False    False
# 2  False     True
# 3   True    False
# 4  False     True

# %%
pd.get_dummies(df4['Area'], drop_first=True, prefix='Area').head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0        True         False
# 1       False         False
# 2       False          True
# 3        True         False
# 4       False          True

# %%
dummy = pd.get_dummies(df4['Area'], drop_first=True, prefix='Area', prefix_sep=' ' )

# %%
dummy.head()
# Out:
#    Area Dhaka  Area Rangpur
# 0        True         False
# 1       False         False
# 2       False          True
# 3        True         False
# 4       False          True

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df4.drop('Area', axis=1, inplace=True)

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
dummy.head()
# Out:
#    Area Dhaka  Area Rangpur
# 0        True         False
# 1       False         False
# 2       False          True
# 3        True         False
# 4       False          True

# %%
#new_df4 = pd.concat([df4, pd.get_dummies(df4['Area'], drop_first=True, prefix='Area', prefix_sep='_' )], axis=1)
new_df4 = pd.concat([df4, dummy], axis=1)

# %%
new_df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83        True
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    Area Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %% [markdown]
# # One-Hot Encoding with LabelBinarizer

# %% [markdown]
# Use `LabelBinarizer` for simple and straightforward binary encoding tasks with low-cardinality categorical features.

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb = LabelBinarizer()
area_encoded = lb.fit_transform(df5['Area'])

area_encoded_df = pd.DataFrame(area_encoded, columns=lb.classes_)
area_encoded_df.head()
# Out:
#    Ctg  Dhaka  Rangpur
# 0    0      1        0
# 1    1      0        0
# 2    0      0        1
# 3    0      1        0
# 4    0      0        1

# %%
lb.classes_
# Out:
# array(['Ctg', 'Dhaka', 'Rangpur'], dtype='<U7')

# %% [markdown]
# #### `Dummy variable trap:`
# This drops the first column from the encoded DataFrame to avoid the dummy variable trap. You can choose any one column to drop.

# %%
# Drop one of the columns to avoid the dummy variable trap
area_encoded_df = area_encoded_df.drop(columns=lb.classes_[0])
area_encoded_df.head()
# Out:
#    Dhaka  Rangpur
# 0      1        0
# 1      0        0
# 2      0        1
# 3      1        0
# 4      0        1

# %%
df5_encoded = pd.concat([df5.drop('Area', axis=1), area_encoded_df], axis=1)
df5_encoded.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Dhaka  Rangpur
# 0        114523.61       136897.80  471784.10  192261.83      1        0
# 1        162597.70       151377.59  443898.53  191792.06      0        0
# 2        153441.51       101145.55  407934.54  191050.39      0        1
# 3        144372.41       118671.85  383199.62  182901.99      1        0
# 4        142107.34        91391.77  366168.42  166187.94      0        1

# %% [markdown]
# # Ordinal Encoding
#
# Ordinal encoding is a technique used to convert categorical data into numerical values based on the order or rank of the categories. This method is useful when the categorical feature has an inherent order or hierarchy.
#
# ## When to Use Ordinal Encoding
#
# Ordinal encoding is appropriate when:
# - The categorical feature has a meaningful order or ranking.
# - You want to preserve the order information in the encoded values.
#
# ## Steps to Perform Ordinal Encoding
#
# 1. **Identify the order or rank of the categories.**
# 2. **Assign numerical values based on the order or rank.**

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df6.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
ordinal = OrdinalEncoder(categories = [['Rangpur','Ctg','Dhaka']])
ordinal
# Out:
# OrdinalEncoder(categories=[['Rangpur', 'Ctg', 'Dhaka']])

# %%
df6.Area = ordinal.fit_transform(df5[['Area']])

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   2.0  192261.83
# 1        162597.70       151377.59  443898.53   1.0  191792.06
# 2        153441.51       101145.55  407934.54   0.0  191050.39
# 3        144372.41       118671.85  383199.62   2.0  182901.99
# 4        142107.34        91391.77  366168.42   0.0  166187.94

# %% [markdown]
# # Binary Encoding

# %% [markdown]
# Binary encoding is a method used to convert categorical data into binary (0s and 1s) features. It reduces the dimensionality compared to one-hot encoding and is useful for high-cardinality features.
# #### Binary Encoding using "category_encoders"
# Use `category_encoders` for more complex encoding needs, especially when dealing with high-cardinality features or when needing specialized encodings like target encoding.

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
import sklearn
import sys
print(sys.executable)
# !{sys.executable} -m pip install category-encoders
sklearn.set_config(transform_output="pandas")
# !pip install category_encoders

import category_encoders as ce
print("✅ category_encoders loaded successfully!")
# Out:
# C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe
# Requirement already satisfied: category-encoders in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from category-encoders) (2.1.3)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from category-encoders) (2.3.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from category-encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from category-encoders) (1.7.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from category-encoders) (1.16.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from category-encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.5->category-encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.5->category-encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.0.5->category-encoders) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category-encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.6.0->category-encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.6.0->category-encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels>=0.9.0->category-encoders) (25.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: category_encoders in c:\users\hp\anaconda3\lib\site-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\hp\anaconda3\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\hp\anaconda3\lib\site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\hp\anaconda3\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from category_encoders) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# ✅ category_encoders loaded successfully!

# %%
BinEn = ce.BinaryEncoder(cols=['Area'])
BinEn
# Out:
# BinaryEncoder(cols=['Area'])

# %%
df7_binary_encoded = BinEn.fit_transform(df)
df7_binary_encoded.head()
# Out:
#    Marketing Spend  Administration  Transport  Area_0  Area_1     Profit
# 0        114523.61       136897.80  471784.10       0       1  192261.83
# 1        162597.70       151377.59  443898.53       1       0  191792.06
# 2        153441.51       101145.55  407934.54       1       1  191050.39
# 3        144372.41       118671.85  383199.62       0       1  182901.99
# 4        142107.34        91391.77  366168.42       1       1  166187.94

# %% [markdown]
# # Mean Encoding

# %% [markdown]
# Mean encoding is typically based on the `target variable` because it aims to capture the relationship between the categorical feature and the target variable. In this case, `y= Profit` is the target variable we want to analyze.

# %%
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
mean_encoded_area = df8.groupby('Area')['Profit'].mean().to_dict()
mean_encoded_area
# Out:
# {'Ctg': 103905.17529411765,
#  'Dhaka': 113756.44647058823,
#  'Rangpur': 118774.02437500001}

# %%
unique_areas = df8['Area'].unique()
unique_areas
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df7['Area'] = df8['Area'].map(mean_encoded_area)
df7.head()
# Out:
#    Marketing Spend  Administration  Transport           Area     Profit
# 0        114523.61       136897.80  471784.10  113756.446471  192261.83
# 1        162597.70       151377.59  443898.53  103905.175294  191792.06
# 2        153441.51       101145.55  407934.54  118774.024375  191050.39
# 3        144372.41       118671.85  383199.62  113756.446471  182901.99
# 4        142107.34        91391.77  366168.42  118774.024375  166187.94

# %% [markdown]
# # Frequency Encoding
#
# Frequency encoding is a technique where categorical features are replaced with their frequency counts. This method can be useful when the frequency of categories holds meaningful information for the model.
#
# #### Steps to Perform Frequency Encoding
#
# 1. **Calculate the frequency of each category.**
# 2. **Replace each category with its frequency count.**

# %%
df9 = df.copy()
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
frequency_encoding = df9['Area'].value_counts().to_dict()
frequency_encoding
# Out:
# {'Dhaka': 17, 'Ctg': 17, 'Rangpur': 16}

# %%
df['Area_Frequency_Encoded'] = df['Area'].map(frequency_encoding)
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94
#
#    Area_Frequency_Encoded
# 0                      17
# 1                      17
# 2                      16
# 3                      17
# 4                      16

# %%
df.drop('Area', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  \
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94
#
#    Area_Frequency_Encoded
# 0                      17
# 1                      17
# 2                      16
# 3                      17
# 4                      16
